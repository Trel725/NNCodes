# %%
import tensorflow as tf
from tensorflow.keras.layers import *
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import *

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
from sklearn.model_selection import train_test_split
import tensorflow.keras.backend as K

# %% [markdown]
# Enable memory growth for GPU, it is needed on some systems for convolution to work.

# %%
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    for gpu in gpus:
        tf.config.experimental.set_memory_growth(gpu, True)

# %% [markdown]
# Load the images dataset and normalize it to [0..1] range We will use only its train part, so skip the testing.

# %%
(x_train, y_train), (_ , _) = tf.keras.datasets.mnist.load_data()
datax = x_train/255.0
labels = tf.keras.utils.to_categorical(y_train)

# %% [markdown]
# Define dimensionality of the input data, of latent space and leaking coefficient for LeakyReLU units. Please note that 2D latent space is inadequate for complex data description such as spectra, so prediction will probably be far from perfection, but it will allow us to visualize the space later.

# %%
inp_dim = datax.shape[1:3]
n_classes = labels.shape[1]
hidden_dim = 2
a = 0.1

# %% [markdown]
# Reparametrization trick - instead of sampling from $q(Z|X)=\mathcal{N}(\mu(X,\theta),\Sigma(X,\theta))$, which is indifferentiable, we sample from $\mathcal{N}(0,1)$ and use properties of normal distribution, namely
# $$ X \sim \mathcal{N}(0,1) \\
# \Sigma^{1/2}X+\mathbf{\mu} \sim \mathcal{N}(\mathbf{\mu}, \Sigma)$$
# to shift mean and scale variance. We've assumed diagonality of $\Sigma$, so multiplication by $\Sigma^{1/2}$ can be replaced with pointwise multiplication by the vector of diagonal standard deviations $\sqrt{\mathbf{\sigma^2}}$, predicted by the encoder.
#
# Since later calculation involve taking log of the variance, it is useful to assume that NN model already predicts log of variance, which will save us from getting NaNs if model output negative number. Thus, here we need to exponentiate log of variance to get $\mathbf{\sigma}^2$, or even better divide by two before exponentiation to directly get $\mathbf{\sigma}$

# %%
def reparametrization(mu, log_sigma):
    batch_size = tf.shape(mu)[0]
    epsilon = tf.random.normal(shape=(batch_size, hidden_dim), mean=0.0, stddev=1.0)
    return tf.math.exp(log_sigma/2)*epsilon+mu

# %% [markdown]
# Now define convolutional encoder model. Predicted $\mathbf{\mu}$ and $\mathbf{\sigma}$ are used to sample from $q(Z|X,Y)$. Additionally, we will create the second input and feed class information as well.

# %%
data_input = Input(shape=(inp_dim[0],inp_dim[1],1))

labels_input = Input(shape=(n_classes,))

x = Conv2D(4, (3,3), padding="same")(data_input)
x = LeakyReLU(a)(x)
x = MaxPool2D((2,2))(x)

x = Conv2D(4, (3,3), padding="same")(x)
x = LeakyReLU(a)(x)
x = MaxPool2D((2,2))(x)

x = Conv2D(8, (3,3), padding="same")(x)
x = LeakyReLU(a)(x)

x = Flatten()(x)

x = Concatenate()([x, labels_input])

x = Dense(100, activation="linear")(x)
x = LeakyReLU(a)(x)

x = Dense(100, activation="linear")(x)
x = LeakyReLU(a)(x)

mu = Dense(hidden_dim, activation="linear")(x)
log_sigma_diag = Dense(hidden_dim, activation="linear")(x)

enc_out = reparametrization(mu, log_sigma_diag)

encoder = Model([data_input, labels_input], enc_out)

# %% [markdown]
# Similarly, define decoder, that approximates $p(X|Z,Y)$. Note that model is defined as mapping from both hidden input and labels input to the reconstructed version, i.e. labels_input is used simultaniously by both parts of the model.

# %%
hidden_input = Input(shape=(hidden_dim,))

x = Concatenate()([hidden_input, labels_input])
x = Dense(100, activation="linear")(x)
x = LeakyReLU(a)(x)

x = Dense(100, activation="linear")(x)
x = LeakyReLU(a)(x)

x = Dense(8*inp_dim[0]//4*inp_dim[1]//4, activation="linear")(x)
x = LeakyReLU(a)(x)

x = Reshape((inp_dim[0]//4, inp_dim[1]//4, 8))(x)

x = Conv2D(8, (3,3), padding="same")(x)
x = LeakyReLU(a)(x)
x = UpSampling2D((2,2))(x)

x = Conv2D(4, (3,3), padding="same")(x)
x = LeakyReLU(a)(x)
x = UpSampling2D((2,2))(x)

x = Conv2D(1, (3,3), padding="same")(x)
dec_out = LeakyReLU(a)(x)

decoder = Model([hidden_input, labels_input], dec_out)

# %% [markdown]
# Now, the optimization criterion is given by:
#     $$\mathbb{E}_{X\sim D}\Big[\mathbb{E}_{\mathcal{E}\sim\mathcal{N}(\mathbf{0},I)}\big[\text{log}\,p\big(X|z=\mu(X,\theta_{1})+\sigma^{2}(X,Y,\theta_{1})\mathcal{E}\big)\big]-D_{KL}[q(Z|X,Y,\theta_{2})||p(Z)]\Big]$$
# Its first part maximizes probability to observe the data $X$ at the decoder output. We will replace it with reconstruction loss, a simple sum of squared errors.

# %%
def sse_loss(X_true, X_reconst):
    loss = K.sum((X_true - X_reconst)**2, axis=[-1,-2,-3])
    return  loss

# %% [markdown]
# The second part of the optimization criterion minimizes Kullback-Leibler divergence between encoder output and its desired shape ($\mathcal{N}(\mathbf{0},I)$ in that case). The divergence is given by $$\frac{1}{2}[\text{tr}\,\Sigma(X)+\mu(X)^{T}\mu(X)-k-\text{log}\,\det\Sigma(X)]$$
#
# since our model already outputs logarithm of the $\Sigma$ diagonal, we need to exponentiate and sum it to get $\text{tr}\,\Sigma(X)$, vector $\mu$ can be squared elementwise and added. Determinant of diagonal matrix is equal to the the product of diagonal elements, and since we already have logarithms of them it simplifies to the summation of the vector of logarithms. Since all three summation are performed over same exis (hidden space dimensionality) we wil replace them by a single sum and subtract $k$. As a final step we use K.mean to get average divergence over batch.

# %%
kl_loss =  0.5*(K.sum(K.exp(log_sigma_diag) + mu**2 - log_sigma_diag, axis=-1) - hidden_dim)
kl_loss = K.mean(kl_loss)

# %% [markdown]
# Now, with everything setup we can define the VAE model as mapping from encoder input (provided labels input) to the decoder output and add the KL loss to it (since it is independent on the model inputs and outputs it can't be passed at model compile step).

# %%
vae = Model([data_input, labels_input], decoder([enc_out, labels_input]))
vae.add_loss(kl_loss)

# %% [markdown]
# Here we will add reconstruction loss and compile the model with adam optimizer.

# %%
vae.compile(loss=sse_loss, optimizer="adam")

# %% [markdown]
# And train the model.

# %%
vae.fit([datax[:,:,:,np.newaxis], labels], datax[:,:,:,np.newaxis], batch_size=32, epochs=50)
# Out:
# Train on 60000 samples
# Epoch 1/50
# 60000/60000 [==============================] - 9s 152us/sample - loss: 35.3679
# Epoch 2/50
# 60000/60000 [==============================] - 8s 126us/sample - loss: 32.0163
# Epoch 3/50
# 60000/60000 [==============================] - 7s 125us/sample - loss: 31.2806
# Epoch 4/50
# 60000/60000 [==============================] - 7s 123us/sample - loss: 30.8939
# Epoch 5/50
# 60000/60000 [==============================] - 8s 126us/sample - loss: 30.6849
# Epoch 6/50
# 60000/60000 [==============================] - 7s 124us/sample - loss: 30.5228
# Epoch 7/50
# 60000/60000 [==============================] - 8s 126us/sample - loss: 30.3883
# Epoch 8/50
# 60000/60000 [==============================] - 8s 126us/sample - loss: 30.2873
# Epoch 9/50
# 60000/60000 [==============================] - 7s 124us/sample - loss: 30.2040
# Epoch 10/50
# 60000/60000 [==============================] - 8s 126us/sample - loss: 30.1214
# Epoch 11/50
# 60000/60000 [==============================] - 8s 126us/sample - loss: 30.0531
# Epoch 12/50
# 60000/60000 [==============================] - 7s 125us/sample - loss: 29.9983
# Epoch 13/50
# 60000/60000 [==============================] - 7s 124us/sample - loss: 29.9471
# Epoch 14/50
# 60000/60000 [==============================] - 8s 126us/sample - loss: 29.8868
# Epoch 15/50
# 60000/60000 [==============================] - 8s 126us/sample - loss: 29.8542
# Epoch 16/50
# 60000/60000 [==============================] - 8s 126us/sample - loss: 29.8156
# Epoch 17/50
# 60000/60000 [==============================] - 8s 128us/sample - loss: 29.7652
# Epoch 18/50
# 60000/60000 [==============================] - 8s 126us/sample - loss: 29.7229
# Epoch 19/50
# 60000/60000 [==============================] - 7s 124us/sample - loss: 29.6913
# Epoch 20/50
# 60000/60000 [==============================] - 7s 125us/sample - loss: 29.6584
# Epoch 21/50
# 60000/60000 [==============================] - 7s 122us/sample - loss: 29.6251
# Epoch 22/50
# 60000/60000 [==============================] - 7s 123us/sample - loss: 29.6020
# Epoch 23/50
# 60000/60000 [==============================] - 7s 125us/sample - loss: 29.5837
# Epoch 24/50
# 60000/60000 [==============================] - 7s 125us/sample - loss: 29.5434
# Epoch 25/50
# 60000/60000 [==============================] - 7s 125us/sample - loss: 29.5203
# Epoch 26/50
# 60000/60000 [==============================] - 8s 126us/sample - loss: 29.4870
# Epoch 27/50
# 60000/60000 [==============================] - 7s 125us/sample - loss: 29.4846
# Epoch 28/50
# 60000/60000 [==============================] - 8s 126us/sample - loss: 29.4657
# Epoch 29/50
# 60000/60000 [==============================] - 7s 125us/sample - loss: 29.4359
# Epoch 30/50
# 60000/60000 [==============================] - 8s 126us/sample - loss: 29.4035
# Epoch 31/50
# 60000/60000 [==============================] - 7s 123us/sample - loss: 29.3848
# Epoch 32/50
# 60000/60000 [==============================] - 7s 123us/sample - loss: 29.3535
# Epoch 33/50
# 60000/60000 [==============================] - 7s 124us/sample - loss: 29.3595
# Epoch 34/50
# 60000/60000 [==============================] - 7s 122us/sample - loss: 29.3314
# Epoch 35/50
# 60000/60000 [==============================] - 7s 123us/sample - loss: 29.3032
# Epoch 36/50
# 60000/60000 [==============================] - 7s 125us/sample - loss: 29.3121
# Epoch 37/50
# 60000/60000 [==============================] - 7s 123us/sample - loss: 29.2924
# Epoch 38/50
# 60000/60000 [==============================] - 7s 124us/sample - loss: 29.2635
# Epoch 39/50
# 60000/60000 [==============================] - 7s 122us/sample - loss: 29.2440
# Epoch 40/50
# 60000/60000 [==============================] - 7s 125us/sample - loss: 29.2513
# Epoch 41/50
# 60000/60000 [==============================] - 8s 127us/sample - loss: 29.2330
# Epoch 42/50
# 60000/60000 [==============================] - 8s 126us/sample - loss: 29.2023
# Epoch 43/50
# 60000/60000 [==============================] - 7s 123us/sample - loss: 29.1870
# Epoch 44/50
# 60000/60000 [==============================] - 8s 126us/sample - loss: 29.1742
# Epoch 45/50
# 60000/60000 [==============================] - 8s 126us/sample - loss: 29.1719
# Epoch 46/50
# 60000/60000 [==============================] - 7s 124us/sample - loss: 29.1459
# Epoch 47/50
# 60000/60000 [==============================] - 8s 125us/sample - loss: 29.1421
# Epoch 48/50
# 60000/60000 [==============================] - 8s 126us/sample - loss: 29.1150
# Epoch 49/50
# 60000/60000 [==============================] - 8s 126us/sample - loss: 29.1203
# Epoch 50/50
# 60000/60000 [==============================] - 7s 124us/sample - loss: 29.1014

# %% [markdown]
# Tune visual parameters.

# %%
matplotlib.style.use("ggplot")
matplotlib.rcParams['figure.figsize'] = (8,6)

# %% [markdown]
# Have a look at the hidden space distibution, which is almost perfectly normal now. No clusters are create since this information is explicitly present in the model.

# %%
emb = encoder.predict([datax[0:3000,:,:,np.newaxis], labels[0:3000]])
scat = plt.scatter(emb[:,0], emb[:,1], c=y_train[:3000], marker=".", cmap="tab10")
plt.legend(*scat.legend_elements())

# %% [markdown]
# Now, the most interesting part. Now we can explore latent space by sampling various points on the grid and decoding them by the decoder, providing the desired label. In that way, we can generate new images and get some understanding of hidden space structure.

# %%
matplotlib.rcParams['figure.figsize'] = (10, 10)

grsize = (15, 15)

xgrid = np.linspace(-2, 2, grsize[0])
ygrid = np.linspace(-2, 2, grsize[1])

for label in np.unique(labels, axis=0):
    idx = 1
    for x in xgrid:
        for y in ygrid:
            decoded = decoder([np.array([[x, y]]), label[np.newaxis,:]]).numpy()
            plt.subplot(grsize[0], grsize[1], idx)
            plt.imshow(np.squeeze(decoded), cmap="gray")
            plt.axis("off")
            idx += 1
    plt.tight_layout(0.0)
    plt.figure()

# %% [markdown]
# And finally, we can try to generate images in the style of reference samples. To do it we generate the samples of images, map them into latent space and encode their latent representation with another class label.

# %%
np.random.seed(15)
ref_label = 5
sample_idx = np.random.choice(np.where(y_train==ref_label)[0], size=10)
samples = datax[sample_idx]

# %% [markdown]
# We will plot the reference image in the first column, left to the generated pictures.

# %%
matplotlib.rcParams['figure.figsize'] = (11, 10)

idx=1
for ref_im in samples:
    style = encoder.predict([ref_im[np.newaxis,:,:,np.newaxis], tf.keras.utils.to_categorical([ref_label], 10)])
    plt.subplot(10,11,idx)
    plt.imshow(np.squeeze(ref_im), cmap="gray")
    plt.axis("off")

    idx+=1
    for label in np.flip(np.unique(labels, axis=0), axis=1):
        im = decoder([style, label[np.newaxis,:]]).numpy()
        plt.subplot(10,11,idx)
        plt.imshow(np.squeeze(im), cmap="gray")
        plt.axis("off")
        idx+=1
plt.tight_layout(0)
